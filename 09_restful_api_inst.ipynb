# %% [markdown]
# ## <strong>9. RESTful API를 이용한 데이터 취득</strong>

# %%
import requests  # HTTP 통신 라이브러리
import matplotlib.pyplot as plt # 데이터 시각화
import time # API 요청 제한(Rate Limit) 우회를 위한 시간 제어

# %%
# 1. 상위 100개 코인 정보 가져오기 (Data Acquisition 단계)
def get_top_100_coins():
    """
    CoinGecko API를 통해 시장의 원천 데이터(Raw Data)를 취득
    """
    url = "https://api.coingecko.com/api/v3/coins/markets"
    
    # API 요청 파라미터 설정
    params = {
        "vs_currency": "usd",        # 통화 단위: USD
        "order": "market_cap_desc",  # 정렬 기준: 시가총액 내림차순
        "per_page": 100,             # 취득할 데이터 양: 100개
        "page": 1,                   # 페이지 번호
        "sparkline": False           # 데이터 부하를 줄이기 위해 그래프 데이터 제외
    }
    
    # RESTful API 호출 (HTTP GET 방식)
    response = requests.get(url, params=params)
    
    # 응답받은 JSON 데이터를 파이썬 객체로 변환
    return response.json()

# %%
# 2. 특정 코인의 시가총액 추이 가져오기
def get_market_chart(coin_id):
    """
    특정 코인의 ID를 사용하여 시계열 데이터를 요청
    """
    url = f"https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart"
    params = {
        "vs_currency": "usd",
        "days": 365,          # 데이터 범위: 최근 365일
        "interval": "daily"   # 데이터 간격: 일 단위 (데이터 정제 과정)
    }
    
    response = requests.get(url, params=params)
    
    # HTTP 상태 코드가 200(성공)일 경우에만 데이터 반환 (예외 처리)
    if response.status_code == 200:
        return response.json()["market_caps"]
    else:
        # 데이터 취득 실패 시 빈 리스트 반환
        return []

# %%
# 3. 시각화 함수 
def plot_market_caps(coin_data):
    """
    가공된 데이터를 바탕으로 분석용 차트를 생성
    """
    plt.figure(figsize=(16, 10))

    for coin_name, market_caps in coin_data.items():
        if not market_caps:
            continue
            
        timestamps = [cap[0] for cap in market_caps] # x축: 타임스탬프
        
        # 데이터 스케일링: 가독성을 위해 달러 단위를 10억(Billion) 단위로 변환
        values = [cap[1] / 1e9 for cap in market_caps] 
        
        plt.plot(timestamps, values, label=coin_name)

    # 시각화
    plt.title("Top 100 Alt Coins - Market Cap Trend (Last 365 Days)")
    plt.xlabel("Timestamp")
    plt.ylabel("Market Cap (Billion USD)")
    plt.xticks(rotation=45)
    plt.legend(fontsize="small", loc="upper left", ncol=2)
    plt.tight_layout()
    plt.grid(True)
    plt.show()

# %%
# --- 메인 실행 흐름 ---

print("🚀 상위 100개 코인 정보를 불러오는 중...")
all_coins = get_top_100_coins()

# 데이터 필터링: 시장 지배력이 너무 큰 BTC, ETH를 제외하여 주요 알트코인들의 추이를 비교
coins = all_coins[2:] 

coin_market_data = {}

# 반복문을 통한 대량 데이터 취득
for i, coin in enumerate(coins):
    coin_id = coin["id"]
    coin_name = coin["name"]
    
    print(f"📈 데이터 수집 중: {coin_name} ({i+1}/100)")
    market_caps = get_market_chart(coin_id)
    
    # 딕셔너리에 데이터 적재
    coin_market_data[coin_name] = market_caps
    
    # API 요청 제한 우회
    time.sleep(1.2) 

    # 실습 효율을 위해 상위 4개 알트코인만 수집 후 중단
    if i >= 3: 
        break
# Out:
# 🚀 상위 100개 코인 정보를 불러오는 중...
# 📈 데이터 수집 중: Tether (1/100)
# 📈 데이터 수집 중: BNB (2/100)
# 📈 데이터 수집 중: XRP (3/100)
# 📈 데이터 수집 중: USDC (4/100)

# %%
# 최종 가공된 데이터를 시각화
plot_market_caps(coin_market_data)

# %%
# get_top_100_coins() 응답 내용(JSON) 확인
coins
# Out:
# [{'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661',
#   'current_price': 1.0,
#   'market_cap': 184731547122,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 190200177823,
#   'total_volume': 91655081849,
#   'high_24h': 1.0,
#   'low_24h': 0.999792,
#   'price_change_24h': 0.00026384,
#   'price_change_percentage_24h': 0.02638,
#   'market_cap_change_24h': 278568796,
#   'market_cap_change_percentage_24h': 0.15102,
#   'circulating_supply': 184674430497.4122,
#   'total_supply': 190141370368.7762,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.39559,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 74.7217,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:46.596Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970',
#   'current_price': 618.52,
#   'market_cap': 84343996527,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': 84343996527,
#   'total_volume': 1430491235,
#   'high_24h': 618.62,
#   'low_24h': 596.28,
#   'price_change_24h': 21.09,
#   'price_change_percentage_24h': 3.52934,
#   'market_cap_change_24h': 2916813891,
#   'market_cap_change_percentage_24h': 3.58211,
#   'circulating_supply': 136356354.04,
#   'total_supply': 136356354.04,
#   'max_supply': 200000000.0,
#   'ath': 1369.99,
#   'ath_change_percentage': -54.8525,
#   'ath_date': '2025-10-13T08:41:24.131Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 1553271.93147,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:46.445Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442',
#   'current_price': 1.37,
#   'market_cap': 84324061993,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 137303579773,
#   'total_volume': 2902009365,
#   'high_24h': 1.38,
#   'low_24h': 1.32,
#   'price_change_24h': 0.04718585,
#   'price_change_percentage_24h': 3.55837,
#   'market_cap_change_24h': 2901518649,
#   'market_cap_change_percentage_24h': 3.56353,
#   'circulating_supply': 61405531717.0,
#   'total_supply': 99985687636.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.65,
#   'ath_change_percentage': -62.33966,
#   'ath_date': '2025-07-18T03:40:53.808Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 51021.84504,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:46.872Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USDC',
#   'image': 'https://coin-images.coingecko.com/coins/images/6319/large/USDC.png?1769615602',
#   'current_price': 0.999747,
#   'market_cap': 78733434030,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 78734243790,
#   'total_volume': 18373376734,
#   'high_24h': 1.0,
#   'low_24h': 0.99801,
#   'price_change_24h': -0.000107467802335504,
#   'price_change_percentage_24h': -0.01075,
#   'market_cap_change_24h': 129036440,
#   'market_cap_change_percentage_24h': 0.16416,
#   'circulating_supply': 78752946646.24564,
#   'total_supply': 78753756607.06607,
#   'max_supply': None,
#   'ath': 1.043,
#   'ath_change_percentage': -4.19423,
#   'ath_date': '2018-11-15T00:00:00.000Z',
#   'atl': 0.877647,
#   'atl_change_percentage': 13.90681,
#   'atl_date': '2023-03-11T08:02:13.981Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:47.156Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://coin-images.coingecko.com/coins/images/4128/large/solana.png?1718769756',
#   'current_price': 86.09,
#   'market_cap': 49521493640,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 53761711678,
#   'total_volume': 4753291474,
#   'high_24h': 86.62,
#   'low_24h': 81.74,
#   'price_change_24h': 4.07,
#   'price_change_percentage_24h': 4.95631,
#   'market_cap_change_24h': 2394103029,
#   'market_cap_change_percentage_24h': 5.08007,
#   'circulating_supply': 575141547.2394085,
#   'total_supply': 624387347.0666604,
#   'max_supply': None,
#   'ath': 293.31,
#   'ath_change_percentage': -70.64853,
#   'ath_date': '2025-01-19T11:15:27.957Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 17090.72903,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:46.191Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://coin-images.coingecko.com/coins/images/1094/large/photo_2026-04-13_09-59-16.png?1776048311',
#   'current_price': 0.321463,
#   'market_cap': 30464167737,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 30464179593,
#   'total_volume': 502945829,
#   'high_24h': 0.322179,
#   'low_24h': 0.319321,
#   'price_change_24h': -0.000542894454178711,
#   'price_change_percentage_24h': -0.1686,
#   'market_cap_change_24h': -61480550.5460701,
#   'market_cap_change_percentage_24h': -0.20141,
#   'circulating_supply': 94774649759.2404,
#   'total_supply': 94774686643.9632,
#   'max_supply': None,
#   'ath': 0.431288,
#   'ath_change_percentage': -25.4645,
#   'ath_date': '2024-12-04T00:10:40.323Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 17716.07784,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 168.19100529476643,
#    'currency': 'usd',
#    'percentage': 16819.100529476644},
#   'last_updated': '2026-04-14T09:27:41.338Z'},
#  {'id': 'figure-heloc',
#   'symbol': 'figr_heloc',
#   'name': 'Figure Heloc',
#   'image': 'https://coin-images.coingecko.com/coins/images/68480/large/figure.png?1755863954',
#   'current_price': 1.027,
#   'market_cap': 17091614828,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 17091614828,
#   'total_volume': 14802046,
#   'high_24h': 1.03,
#   'low_24h': 1.017,
#   'price_change_24h': 0.007334,
#   'price_change_percentage_24h': 0.71934,
#   'market_cap_change_24h': 122069469,
#   'market_cap_change_percentage_24h': 0.71934,
#   'circulating_supply': 16644323597.827,
#   'total_supply': 16644323597.827,
#   'max_supply': None,
#   'ath': 1.049,
#   'ath_change_percentage': -2.12036,
#   'ath_date': '2026-03-09T17:00:25.937Z',
#   'atl': 0.155357,
#   'atl_change_percentage': 560.97836,
#   'atl_date': '2025-10-31T14:27:24.456Z',
#   'roi': None,
#   'last_updated': '2026-04-14T05:18:27.512Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/5/large/dogecoin.png?1696501409',
#   'current_price': 0.094536,
#   'market_cap': 14540714057,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 14540718784,
#   'total_volume': 1740114682,
#   'high_24h': 0.094708,
#   'low_24h': 0.090852,
#   'price_change_24h': 0.00349429,
#   'price_change_percentage_24h': 3.83812,
#   'market_cap_change_24h': 537133019,
#   'market_cap_change_percentage_24h': 3.83568,
#   'circulating_supply': 153824036383.7052,
#   'total_supply': 153824086383.7052,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -87.07778,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 108682.54767,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:43.960Z'},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'image': 'https://coin-images.coingecko.com/coins/images/27045/large/wbt_token.png?1696526096',
#   'current_price': 54.97,
#   'market_cap': 11733272348,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 17574656548,
#   'total_volume': 82055471,
#   'high_24h': 55.02,
#   'low_24h': 51.95,
#   'price_change_24h': 2.99,
#   'price_change_percentage_24h': 5.75655,
#   'market_cap_change_24h': 641146323,
#   'market_cap_change_percentage_24h': 5.78019,
#   'circulating_supply': 213418274.0,
#   'total_supply': 319668099.0,
#   'max_supply': 400000000.0,
#   'ath': 64.11,
#   'ath_change_percentage': -14.17881,
#   'ath_date': '2025-12-10T20:16:13.582Z',
#   'atl': 3.06,
#   'atl_change_percentage': 1696.92393,
#   'atl_date': '2023-02-13T19:01:21.899Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:42.136Z'},
#  {'id': 'usds',
#   'symbol': 'usds',
#   'name': 'USDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/39926/large/usds.webp?1726666683',
#   'current_price': 0.999751,
#   'market_cap': 11318235374,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 11318235374,
#   'total_volume': 80756942,
#   'high_24h': 1.0,
#   'low_24h': 0.999459,
#   'price_change_24h': -3.9718691909107e-05,
#   'price_change_percentage_24h': -0.00397,
#   'market_cap_change_24h': -184698102.33294868,
#   'market_cap_change_percentage_24h': -1.60566,
#   'circulating_supply': 11321050258.91635,
#   'total_supply': 11321050258.91635,
#   'max_supply': None,
#   'ath': 1.15,
#   'ath_change_percentage': -13.22583,
#   'ath_date': '2026-04-02T07:21:14.655Z',
#   'atl': 0.948265,
#   'atl_change_percentage': 5.42571,
#   'atl_date': '2024-10-03T13:19:28.826Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:43.584Z'},
#  {'id': 'hyperliquid',
#   'symbol': 'hype',
#   'name': 'Hyperliquid',
#   'image': 'https://coin-images.coingecko.com/coins/images/50882/large/hyperliquid.jpg?1729431300',
#   'current_price': 44.92,
#   'market_cap': 10706884415,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': 43219762772,
#   'total_volume': 444089176,
#   'high_24h': 45.12,
#   'low_24h': 41.48,
#   'price_change_24h': 3.35,
#   'price_change_percentage_24h': 8.06631,
#   'market_cap_change_24h': 798472901,
#   'market_cap_change_percentage_24h': 8.05854,
#   'circulating_supply': 238385315.9541414,
#   'total_supply': 962274028.9541414,
#   'max_supply': 1000000000.0,
#   'ath': 59.3,
#   'ath_change_percentage': -24.26122,
#   'ath_date': '2025-09-18T03:30:30.650Z',
#   'atl': 3.81,
#   'atl_change_percentage': 1079.284,
#   'atl_date': '2024-11-29T09:30:30.871Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:43.813Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/8418/large/leo-token.png?1696508607',
#   'current_price': 10.12,
#   'market_cap': 9318382301,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 9970011150,
#   'total_volume': 556566,
#   'high_24h': 10.16,
#   'low_24h': 10.08,
#   'price_change_24h': -0.007812508353929104,
#   'price_change_percentage_24h': -0.07714,
#   'market_cap_change_24h': -7296198.037893295,
#   'market_cap_change_percentage_24h': -0.07824,
#   'circulating_supply': 920845344.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 10.2,
#   'ath_change_percentage': -1.01167,
#   'ath_date': '2026-04-08T16:00:43.393Z',
#   'atl': 0.799859,
#   'atl_change_percentage': 1161.84278,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:45.937Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://coin-images.coingecko.com/coins/images/975/large/cardano.png?1696502090',
#   'current_price': 0.244054,
#   'market_cap': 9023731471,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': 10992525871,
#   'total_volume': 515021651,
#   'high_24h': 0.248701,
#   'low_24h': 0.237798,
#   'price_change_24h': 0.00516993,
#   'price_change_percentage_24h': 2.1642,
#   'market_cap_change_24h': 199216040,
#   'market_cap_change_percentage_24h': 2.25753,
#   'circulating_supply': 36940364839.85039,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -92.0939,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 1167.63353,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:46.451Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://coin-images.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1696501932',
#   'current_price': 437.17,
#   'market_cap': 8750956253,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': 8751073721,
#   'total_volume': 209393309,
#   'high_24h': 439.56,
#   'low_24h': 424.82,
#   'price_change_24h': 12.3,
#   'price_change_percentage_24h': 2.89494,
#   'market_cap_change_24h': 244793110,
#   'market_cap_change_percentage_24h': 2.87783,
#   'circulating_supply': 20020937.39665078,
#   'total_supply': 20021206.14665078,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -88.45238,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 468.23734,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:46.164Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://coin-images.coingecko.com/coins/images/877/large/Chainlink_Logo_500.png?1760023405',
#   'current_price': 9.22,
#   'market_cap': 6710381407,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 9228966690,
#   'total_volume': 457044564,
#   'high_24h': 9.4,
#   'low_24h': 8.7,
#   'price_change_24h': 0.48368,
#   'price_change_percentage_24h': 5.53643,
#   'market_cap_change_24h': 359851224,
#   'market_cap_change_percentage_24h': 5.66648,
#   'circulating_supply': 727099970.4523476,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -82.50355,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 6122.05157,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:53.111Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://coin-images.coingecko.com/coins/images/69/large/monero_logo.png?1696501460',
#   'current_price': 348.4,
#   'market_cap': 6427385489,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 6427385489,
#   'total_volume': 104539312,
#   'high_24h': 349.46,
#   'low_24h': 343.29,
#   'price_change_24h': 2.07,
#   'price_change_percentage_24h': 0.59873,
#   'market_cap_change_24h': 36061558,
#   'market_cap_change_percentage_24h': 0.56423,
#   'circulating_supply': 18446744.07370955,
#   'total_supply': 18446744.07370955,
#   'max_supply': None,
#   'ath': 797.73,
#   'ath_change_percentage': -56.32586,
#   'ath_date': '2026-01-14T19:34:07.049Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 161066.22609,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:45.359Z'},
#  {'id': 'zcash',
#   'symbol': 'zec',
#   'name': 'Zcash',
#   'image': 'https://coin-images.coingecko.com/coins/images/486/large/circle-zcash-color.png?1696501740',
#   'current_price': 377.92,
#   'market_cap': 6290223056,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 6290541688,
#   'total_volume': 579752573,
#   'high_24h': 381.27,
#   'low_24h': 345.51,
#   'price_change_24h': 17.63,
#   'price_change_percentage_24h': 4.89409,
#   'market_cap_change_24h': 288721797,
#   'market_cap_change_percentage_24h': 4.81083,
#   'circulating_supply': 16656784.5405448,
#   'total_supply': 16657628.2905448,
#   'max_supply': 21000000.0,
#   'ath': 3191.93,
#   'ath_change_percentage': -88.1602,
#   'ath_date': '2016-10-29T00:00:00.000Z',
#   'atl': 16.08,
#   'atl_change_percentage': 2250.21813,
#   'atl_date': '2024-07-05T04:22:29.321Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:44.817Z'},
#  {'id': 'canton-network',
#   'symbol': 'cc',
#   'name': 'Canton',
#   'image': 'https://coin-images.coingecko.com/coins/images/70468/large/Canton-Ticker_%281%29.png?1762826299',
#   'current_price': 0.155624,
#   'market_cap': 5967975785,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 5967975785,
#   'total_volume': 27442900,
#   'high_24h': 0.160445,
#   'low_24h': 0.148197,
#   'price_change_24h': 0.00742661,
#   'price_change_percentage_24h': 5.01129,
#   'market_cap_change_24h': 291656934,
#   'market_cap_change_percentage_24h': 5.13814,
#   'circulating_supply': 38307972232.31476,
#   'total_supply': 38307972232.31476,
#   'max_supply': None,
#   'ath': 0.194152,
#   'ath_change_percentage': -19.66047,
#   'ath_date': '2026-02-03T08:02:08.411Z',
#   'atl': 0.059024,
#   'atl_change_percentage': 164.26605,
#   'atl_date': '2025-12-06T10:32:09.784Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:45.676Z'},
#  {'id': 'ethena-usde',
#   'symbol': 'usde',
#   'name': 'Ethena USDe',
#   'image': 'https://coin-images.coingecko.com/coins/images/33613/large/usde.png?1733810059',
#   'current_price': 1.001,
#   'market_cap': 5828624318,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 5828624318,
#   'total_volume': 193025397,
#   'high_24h': 1.001,
#   'low_24h': 0.998774,
#   'price_change_24h': 0.00083402,
#   'price_change_percentage_24h': 0.08343,
#   'market_cap_change_24h': 1885311,
#   'market_cap_change_percentage_24h': 0.03236,
#   'circulating_supply': 5828297804.522167,
#   'total_supply': 5828297804.522167,
#   'max_supply': None,
#   'ath': 1.034,
#   'ath_change_percentage': -3.26389,
#   'ath_date': '2025-12-09T17:10:12.652Z',
#   'atl': 0.929486,
#   'atl_change_percentage': 7.61587,
#   'atl_date': '2024-10-04T07:57:15.809Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:43.075Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://coin-images.coingecko.com/coins/images/100/large/fmpFRHHQ_400x400.jpg?1735231350',
#   'current_price': 0.156835,
#   'market_cap': 5192712381,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 7843848689,
#   'total_volume': 89471592,
#   'high_24h': 0.156992,
#   'low_24h': 0.151188,
#   'price_change_24h': 0.00558461,
#   'price_change_percentage_24h': 3.6923,
#   'market_cap_change_24h': 188008200,
#   'market_cap_change_percentage_24h': 3.75663,
#   'circulating_supply': 33101721889.09949,
#   'total_supply': 50001786883.65895,
#   'max_supply': None,
#   'ath': 0.875563,
#   'ath_change_percentage': -82.08089,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 32852.18505,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:41.105Z'},
#  {'id': 'memecore',
#   'symbol': 'm',
#   'name': 'MemeCore',
#   'image': 'https://coin-images.coingecko.com/coins/images/53247/large/square-bg-transparent.png?1752637478',
#   'current_price': 2.79,
#   'market_cap': 4918208565,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 14993250845,
#   'total_volume': 18596845,
#   'high_24h': 2.99,
#   'low_24h': 2.7,
#   'price_change_24h': -0.11588889121115598,
#   'price_change_percentage_24h': -3.98172,
#   'market_cap_change_24h': -192265031.56927013,
#   'market_cap_change_percentage_24h': -3.76218,
#   'circulating_supply': 1757367397.726114,
#   'total_supply': 5357367397.28539,
#   'max_supply': 10000000000.0,
#   'ath': 2.99,
#   'ath_change_percentage': -5.84851,
#   'ath_date': '2026-04-13T15:05:06.618Z',
#   'atl': 0.04746135,
#   'atl_change_percentage': 5828.49691,
#   'atl_date': '2025-07-04T03:56:17.448Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:44.090Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://coin-images.coingecko.com/coins/images/9956/large/Badge_Dai.png?1696509996',
#   'current_price': 0.999343,
#   'market_cap': 4374471773,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': 4374471773,
#   'total_volume': 74924265,
#   'high_24h': 1.003,
#   'low_24h': 0.994766,
#   'price_change_24h': -0.002496186366215403,
#   'price_change_percentage_24h': -0.24916,
#   'market_cap_change_24h': -49160071.186974525,
#   'market_cap_change_percentage_24h': -1.11131,
#   'circulating_supply': 4377236293.986464,
#   'total_supply': 4377236293.986464,
#   'max_supply': None,
#   'ath': 1.22,
#   'ath_change_percentage': -18.01329,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.88196,
#   'atl_change_percentage': 13.3114,
#   'atl_date': '2023-03-11T07:50:50.514Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:46.188Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/2/large/litecoin.png?1696501400',
#   'current_price': 54.83,
#   'market_cap': 4226474643,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': 4226606280,
#   'total_volume': 410499890,
#   'high_24h': 54.85,
#   'low_24h': 52.71,
#   'price_change_24h': 1.77,
#   'price_change_percentage_24h': 3.33741,
#   'market_cap_change_24h': 138664523,
#   'market_cap_change_percentage_24h': 3.39215,
#   'circulating_supply': 77056614.48347135,
#   'total_supply': 77059014.48347135,
#   'max_supply': 84000000.0,
#   'ath': 410.26,
#   'ath_change_percentage': -86.63422,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 4673.01489,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:42.106Z'},
#  {'id': 'usd1-wlfi',
#   'symbol': 'usd1',
#   'name': 'USD1',
#   'image': 'https://coin-images.coingecko.com/coins/images/54977/large/USD1_1000x1000_transparent.png?1749297002',
#   'current_price': 0.999258,
#   'market_cap': 4079929973,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 4079929973,
#   'total_volume': 1535959962,
#   'high_24h': 0.999955,
#   'low_24h': 0.998656,
#   'price_change_24h': 0.00023572,
#   'price_change_percentage_24h': 0.0236,
#   'market_cap_change_24h': -51211916.48062277,
#   'market_cap_change_percentage_24h': -1.23966,
#   'circulating_supply': 4083298349.062485,
#   'total_supply': 4083298349.062485,
#   'max_supply': None,
#   'ath': 1.025,
#   'ath_change_percentage': -2.4892,
#   'ath_date': '2025-05-12T12:36:39.412Z',
#   'atl': 0.989633,
#   'atl_change_percentage': 0.97847,
#   'atl_date': '2025-10-01T08:51:32.103Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:44.698Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'image': 'https://coin-images.coingecko.com/coins/images/12559/large/Avalanche_Circle_RedWhite_Trans.png?1696512369',
#   'current_price': 9.41,
#   'market_cap': 4062321035,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': 4360279362,
#   'total_volume': 379490355,
#   'high_24h': 9.68,
#   'low_24h': 9.01,
#   'price_change_24h': 0.346525,
#   'price_change_percentage_24h': 3.82455,
#   'market_cap_change_24h': 149107267,
#   'market_cap_change_percentage_24h': 3.81035,
#   'circulating_supply': 431771961.1772119,
#   'total_supply': 463441061.1772119,
#   'max_supply': 720000000.0,
#   'ath': 144.96,
#   'ath_change_percentage': -93.50575,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 2.8,
#   'atl_change_percentage': 236.09145,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:41.592Z'},
#  {'id': 'paypal-usd',
#   'symbol': 'pyusd',
#   'name': 'PayPal USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/31212/large/PYUSD_Token_Logo_2x.png?1765987788',
#   'current_price': 1.0,
#   'market_cap': 4027394855,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': 4027394855,
#   'total_volume': 142406048,
#   'high_24h': 1.0,
#   'low_24h': 0.999454,
#   'price_change_24h': 0.00016359,
#   'price_change_percentage_24h': 0.01636,
#   'market_cap_change_24h': 11340902,
#   'market_cap_change_percentage_24h': 0.28239,
#   'circulating_supply': 4027427526.398032,
#   'total_supply': 4027427526.398032,
#   'max_supply': None,
#   'ath': 1.081,
#   'ath_change_percentage': -7.48299,
#   'ath_date': '2026-04-02T07:35:31.426Z',
#   'atl': 0.959426,
#   'atl_change_percentage': 4.22551,
#   'atl_date': '2024-12-05T22:31:13.430Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:42.789Z'},
#  {'id': 'rain',
#   'symbol': 'rain',
#   'name': 'Rain',
#   'image': 'https://coin-images.coingecko.com/coins/images/69134/large/Rain_logo_1_.png?1762952191',
#   'current_price': 0.00805689,
#   'market_cap': 3854078384,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': 9264662930,
#   'total_volume': 16127291,
#   'high_24h': 0.00819491,
#   'low_24h': 0.00763099,
#   'price_change_24h': 0.00042211,
#   'price_change_percentage_24h': 5.52875,
#   'market_cap_change_24h': 205676596,
#   'market_cap_change_percentage_24h': 5.63744,
#   'circulating_supply': 478357737544.77423,
#   'total_supply': 1149904790981.393,
#   'max_supply': 1150000000000.0,
#   'ath': 0.01090099,
#   'ath_change_percentage': -26.08042,
#   'ath_date': '2026-02-09T16:50:09.904Z',
#   'atl': 0.00222126,
#   'atl_change_percentage': 262.76558,
#   'atl_date': '2025-09-14T08:56:57.416Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:45.336Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://coin-images.coingecko.com/coins/images/3688/large/hbar.png?1696504364',
#   'current_price': 0.086802,
#   'market_cap': 3761910065,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 4341924655,
#   'total_volume': 84450499,
#   'high_24h': 0.087943,
#   'low_24h': 0.084512,
#   'price_change_24h': 0.00163407,
#   'price_change_percentage_24h': 1.91865,
#   'market_cap_change_24h': 73232411,
#   'market_cap_change_percentage_24h': 1.98533,
#   'circulating_supply': 43320766299.18339,
#   'total_supply': 50000000000.0,
#   'max_supply': 50000000000.0,
#   'ath': 0.569229,
#   'ath_change_percentage': -84.73694,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.00986111,
#   'atl_change_percentage': 781.05454,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:43.196Z'},
#  {'id': 'sui',
#   'symbol': 'sui',
#   'name': 'Sui',
#   'image': 'https://coin-images.coingecko.com/coins/images/26375/large/sui-ocean-square.png?1727791290',
#   'current_price': 0.949863,
#   'market_cap': 3756241655,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 9501320814,
#   'total_volume': 383904405,
#   'high_24h': 0.96054,
#   'low_24h': 0.900066,
#   'price_change_24h': 0.04640427,
#   'price_change_percentage_24h': 5.13629,
#   'market_cap_change_24h': 184929280,
#   'market_cap_change_percentage_24h': 5.17819,
#   'circulating_supply': 3953388932.071221,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 5.35,
#   'ath_change_percentage': -82.23415,
#   'ath_date': '2025-01-04T22:56:18.063Z',
#   'atl': 0.364846,
#   'atl_change_percentage': 160.34609,
#   'atl_date': '2023-10-19T10:40:30.078Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:42.450Z'},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/17980/large/photo_2024-09-10_17.09.00.jpeg?1725963446',
#   'current_price': 1.44,
#   'market_cap': 3568159295,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': 7421226112,
#   'total_volume': 111810030,
#   'high_24h': 1.45,
#   'low_24h': 1.4,
#   'price_change_24h': 0.02820795,
#   'price_change_percentage_24h': 2.00337,
#   'market_cap_change_24h': 74165088,
#   'market_cap_change_percentage_24h': 2.12264,
#   'circulating_supply': 2482119837.805706,
#   'total_supply': 5162429990.497584,
#   'max_supply': None,
#   'ath': 8.25,
#   'ath_change_percentage': -82.53942,
#   'ath_date': '2024-06-15T00:36:51.509Z',
#   'atl': 0.519364,
#   'atl_change_percentage': 177.47948,
#   'atl_date': '2021-09-21T00:33:11.092Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:50.046Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://coin-images.coingecko.com/coins/images/11939/large/shiba.png?1696511800',
#   'current_price': 5.93e-06,
#   'market_cap': 3493293590,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 3494814622,
#   'total_volume': 127097709,
#   'high_24h': 6e-06,
#   'low_24h': 5.76e-06,
#   'price_change_24h': 1.59922e-07,
#   'price_change_percentage_24h': 2.77312,
#   'market_cap_change_24h': 96043334,
#   'market_cap_change_percentage_24h': 2.82709,
#   'circulating_supply': 589243521383479.8,
#   'total_supply': 589500086857209.4,
#   'max_supply': None,
#   'ath': 8.616e-05,
#   'ath_change_percentage': -93.12108,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 5.6366e-11,
#   'atl_change_percentage': 10514662.27383,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:41.276Z'},
#  {'id': 'ravedao',
#   'symbol': 'rave',
#   'name': 'RaveDAO',
#   'image': 'https://coin-images.coingecko.com/coins/images/70544/large/coin.jpeg?1762452940',
#   'current_price': 14.07,
#   'market_cap': 3444799473,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': 13887831621,
#   'total_volume': 653552304,
#   'high_24h': 14.18,
#   'low_24h': 7.49,
#   'price_change_24h': 5.42,
#   'price_change_percentage_24h': 62.76251,
#   'market_cap_change_24h': 1302470656,
#   'market_cap_change_percentage_24h': 60.79695,
#   'circulating_supply': 248044444.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 14.18,
#   'ath_change_percentage': -2.83456,
#   'ath_date': '2026-04-13T19:40:14.919Z',
#   'atl': 0.206266,
#   'atl_change_percentage': 6577.48609,
#   'atl_date': '2026-03-12T02:10:18.440Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:45.689Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Cronos',
#   'image': 'https://coin-images.coingecko.com/coins/images/7310/large/cro_token_logo.png?1696507599',
#   'current_price': 0.070812,
#   'market_cap': 2999026601,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': 6978744760,
#   'total_volume': 13183965,
#   'high_24h': 0.070834,
#   'low_24h': 0.068152,
#   'price_change_24h': 0.00250393,
#   'price_change_percentage_24h': 3.66566,
#   'market_cap_change_24h': 107271218,
#   'market_cap_change_percentage_24h': 3.70955,
#   'circulating_supply': 42351025466.16557,
#   'total_supply': 98550975495.89444,
#   'max_supply': 100000000000.0,
#   'ath': 0.891544,
#   'ath_change_percentage': -92.05495,
#   'ath_date': '2021-11-24T00:00:00.000Z',
#   'atl': 0.0121196,
#   'atl_change_percentage': 484.45561,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:45.964Z'},
#  {'id': 'hashnote-usyc',
#   'symbol': 'usyc',
#   'name': 'Circle USYC',
#   'image': 'https://coin-images.coingecko.com/coins/images/51054/large/Hashnote_SDYC_200x200.png?1730370965',
#   'current_price': 1.12,
#   'market_cap': 2682492844,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 2682492844,
#   'total_volume': 112099,
#   'high_24h': None,
#   'low_24h': None,
#   'price_change_24h': None,
#   'price_change_percentage_24h': None,
#   'market_cap_change_24h': None,
#   'market_cap_change_percentage_24h': None,
#   'circulating_supply': 2392972188.222456,
#   'total_supply': 2392972188.222456,
#   'max_supply': None,
#   'ath': 1.12,
#   'ath_change_percentage': -0.09236,
#   'ath_date': '2026-04-08T14:31:05.529Z',
#   'atl': 1.026,
#   'atl_change_percentage': 9.24713,
#   'atl_date': '2024-12-05T22:31:20.475Z',
#   'roi': None,
#   'last_updated': '2026-04-09T23:06:04.591Z'},
#  {'id': 'tether-gold',
#   'symbol': 'xaut',
#   'name': 'Tether Gold',
#   'image': 'https://coin-images.coingecko.com/coins/images/10481/large/logo.png?1774627372',
#   'current_price': 4763.52,
#   'market_cap': 2666488123,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 3371812519,
#   'total_volume': 367639292,
#   'high_24h': 4768.1,
#   'low_24h': 4677.98,
#   'price_change_24h': 68.78,
#   'price_change_percentage_24h': 1.46499,
#   'market_cap_change_24h': 38693478,
#   'market_cap_change_percentage_24h': 1.47247,
#   'circulating_supply': 559698.736688,
#   'total_supply': 707747.089,
#   'max_supply': None,
#   'ath': 5504.62,
#   'ath_change_percentage': -13.46086,
#   'ath_date': '2026-01-29T00:00:00.000Z',
#   'atl': 1447.84,
#   'atl_change_percentage': 229.01725,
#   'atl_date': '2020-03-19T13:45:41.821Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:41.209Z'},
#  {'id': 'world-liberty-financial',
#   'symbol': 'wlfi',
#   'name': 'World Liberty Financial',
#   'image': 'https://coin-images.coingecko.com/coins/images/50767/large/wlfi.png?1756438915',
#   'current_price': 0.080709,
#   'market_cap': 2562420989,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 8067364534,
#   'total_volume': 74399160,
#   'high_24h': 0.082157,
#   'low_24h': 0.078971,
#   'price_change_24h': 0.00137719,
#   'price_change_percentage_24h': 1.73598,
#   'market_cap_change_24h': 45098320,
#   'market_cap_change_percentage_24h': 1.79152,
#   'circulating_supply': 31762801571.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 0.331336,
#   'ath_change_percentage': -75.64123,
#   'ath_date': '2025-09-01T12:20:09.597Z',
#   'atl': 0.07726,
#   'atl_change_percentage': 4.4644,
#   'atl_date': '2026-04-11T07:56:04.528Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:44.040Z'},
#  {'id': 'blackrock-usd-institutional-digital-liquidity-fund',
#   'symbol': 'buidl',
#   'name': 'BlackRock USD Institutional Digital Liquidity Fund',
#   'image': 'https://coin-images.coingecko.com/coins/images/36291/large/blackrock.png?1711013223',
#   'current_price': 1.0,
#   'market_cap': 2443379496,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 2443379496,
#   'total_volume': 0.0,
#   'high_24h': 1.0,
#   'low_24h': 1.0,
#   'price_change_24h': 0.0,
#   'price_change_percentage_24h': 0.0,
#   'market_cap_change_24h': 0.0,
#   'market_cap_change_percentage_24h': 0.0,
#   'circulating_supply': 2443379495.530449,
#   'total_supply': 2443379495.530449,
#   'max_supply': None,
#   'ath': 1.0,
#   'ath_change_percentage': 0.0,
#   'ath_date': '2025-02-12T05:00:10.912Z',
#   'atl': 1.0,
#   'atl_change_percentage': 0.0,
#   'atl_date': '2025-02-12T05:45:10.196Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:25:01.305Z'},
#  {'id': 'pax-gold',
#   'symbol': 'paxg',
#   'name': 'PAX Gold',
#   'image': 'https://coin-images.coingecko.com/coins/images/9519/large/paxgold.png?1696509604',
#   'current_price': 4771.74,
#   'market_cap': 2422662640,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': 2422662640,
#   'total_volume': 289450304,
#   'high_24h': 4777.84,
#   'low_24h': 4688.85,
#   'price_change_24h': 69.86,
#   'price_change_percentage_24h': 1.48579,
#   'market_cap_change_24h': 35609443,
#   'market_cap_change_percentage_24h': 1.49177,
#   'circulating_supply': 507641.795,
#   'total_supply': 507641.795,
#   'max_supply': None,
#   'ath': 5619.09,
#   'ath_change_percentage': -15.07869,
#   'ath_date': '2026-01-29T06:30:56.612Z',
#   'atl': 1399.64,
#   'atl_change_percentage': 240.93055,
#   'atl_date': '2019-11-18T03:09:35.959Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:49.752Z'},
#  {'id': 'bittensor',
#   'symbol': 'tao',
#   'name': 'Bittensor',
#   'image': 'https://coin-images.coingecko.com/coins/images/28452/large/ARUsPeNQ_400x400.jpeg?1696527447',
#   'current_price': 252.33,
#   'market_cap': 2422032095,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': 5299580275,
#   'total_volume': 285508151,
#   'high_24h': 263.69,
#   'low_24h': 251.15,
#   'price_change_24h': -7.008244342603064,
#   'price_change_percentage_24h': -2.7024,
#   'market_cap_change_24h': -69793625.62952757,
#   'market_cap_change_percentage_24h': -2.8009,
#   'circulating_supply': 9597491.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 757.6,
#   'ath_change_percentage': -66.68259,
#   'ath_date': '2024-03-07T18:45:36.466Z',
#   'atl': 30.83,
#   'atl_change_percentage': 718.73054,
#   'atl_date': '2023-05-14T08:57:53.732Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:42.419Z'},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'image': 'https://coin-images.coingecko.com/coins/images/30980/large/MNT_Token_Logo.png?1765516974',
#   'current_price': 0.681909,
#   'market_cap': 2235750249,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 4241939105,
#   'total_volume': 37283991,
#   'high_24h': 0.687403,
#   'low_24h': 0.661999,
#   'price_change_24h': 0.01991008,
#   'price_change_percentage_24h': 3.00757,
#   'market_cap_change_24h': 65453020,
#   'market_cap_change_percentage_24h': 3.01586,
#   'circulating_supply': 3277944055.53684,
#   'total_supply': 6219316794.889999,
#   'max_supply': 6219316794.89,
#   'ath': 2.86,
#   'ath_change_percentage': -76.10381,
#   'ath_date': '2025-10-09T01:04:46.659Z',
#   'atl': 0.307978,
#   'atl_change_percentage': 121.52585,
#   'atl_date': '2023-10-18T02:50:46.942Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:50.366Z'},
#  {'id': 'global-dollar',
#   'symbol': 'usdg',
#   'name': 'Global Dollar',
#   'image': 'https://coin-images.coingecko.com/coins/images/51281/large/GDN_USDG_Token_200x200.png?1730484111',
#   'current_price': 0.999947,
#   'market_cap': 2159446458,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 2159446458,
#   'total_volume': 73095422,
#   'high_24h': 1.0,
#   'low_24h': 0.999741,
#   'price_change_24h': 1.273e-05,
#   'price_change_percentage_24h': 0.00127,
#   'market_cap_change_24h': 27089836,
#   'market_cap_change_percentage_24h': 1.27042,
#   'circulating_supply': 2159590280.873684,
#   'total_supply': 2159590280.873684,
#   'max_supply': None,
#   'ath': 1.65,
#   'ath_change_percentage': -39.56922,
#   'ath_date': '2025-01-30T00:11:05.728Z',
#   'atl': 0.907561,
#   'atl_change_percentage': 10.16744,
#   'atl_date': '2024-11-11T23:55:50.604Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:43.934Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://coin-images.coingecko.com/coins/images/12504/large/uniswap-logo.png?1720676669',
#   'current_price': 3.2,
#   'market_cap': 2023390007,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': 2864651384,
#   'total_volume': 213763561,
#   'high_24h': 3.25,
#   'low_24h': 3.01,
#   'price_change_24h': 0.156422,
#   'price_change_percentage_24h': 5.14726,
#   'market_cap_change_24h': 98118390,
#   'market_cap_change_percentage_24h': 5.09634,
#   'circulating_supply': 633561603.6037512,
#   'total_supply': 896976420.0366304,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -92.88178,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 210.37258,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:41.805Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://coin-images.coingecko.com/coins/images/12171/large/polkadot.jpg?1766533446',
#   'current_price': 1.19,
#   'market_cap': 2001809962,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 2001809962,
#   'total_volume': 297808384,
#   'high_24h': 1.24,
#   'low_24h': 1.16,
#   'price_change_24h': 0.00898662,
#   'price_change_percentage_24h': 0.75904,
#   'market_cap_change_24h': 14059571,
#   'market_cap_change_percentage_24h': 0.70731,
#   'circulating_supply': 1679150695.584071,
#   'total_supply': 1679150695.584071,
#   'max_supply': 2100000000.0,
#   'ath': 54.98,
#   'ath_change_percentage': -97.83141,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 1.15,
#   'atl_change_percentage': 3.64875,
#   'atl_date': '2026-02-06T00:25:45.413Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:41.369Z'},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'NEAR Protocol',
#   'image': 'https://coin-images.coingecko.com/coins/images/10365/large/near.jpg?1696510367',
#   'current_price': 1.42,
#   'market_cap': 1831867232,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 1831867250,
#   'total_volume': 239675345,
#   'high_24h': 1.44,
#   'low_24h': 1.37,
#   'price_change_24h': 0.03319001,
#   'price_change_percentage_24h': 2.39715,
#   'market_cap_change_24h': 40807674,
#   'market_cap_change_percentage_24h': 2.27841,
#   'circulating_supply': 1292839128.0,
#   'total_supply': 1292839141.0,
#   'max_supply': None,
#   'ath': 20.44,
#   'ath_change_percentage': -93.06985,
#   'ath_date': '2022-01-16T22:09:45.873Z',
#   'atl': 0.526762,
#   'atl_change_percentage': 168.88655,
#   'atl_date': '2020-11-04T16:09:15.137Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:41.222Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://coin-images.coingecko.com/coins/images/4463/large/WeChat_Image_20220118095654.png?1696505053',
#   'current_price': 85.25,
#   'market_cap': 1790612479,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': 1790612479,
#   'total_volume': 15912462,
#   'high_24h': 85.38,
#   'low_24h': 82.7,
#   'price_change_24h': 2.44,
#   'price_change_percentage_24h': 2.94937,
#   'market_cap_change_24h': 51702517,
#   'market_cap_change_percentage_24h': 2.97327,
#   'circulating_supply': 21000000.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 228.74,
#   'ath_change_percentage': -62.67306,
#   'ath_date': '2025-10-05T00:00:00.000Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 14605.51932,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:43.766Z'},
#  {'id': 'falcon-finance',
#   'symbol': 'usdf',
#   'name': 'Falcon USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/54558/large/ff_200_X_200.png?1740741076',
#   'current_price': 0.998149,
#   'market_cap': 1786580635,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 1786580635,
#   'total_volume': 817495,
#   'high_24h': 0.998752,
#   'low_24h': 0.997451,
#   'price_change_24h': 0.0002034,
#   'price_change_percentage_24h': 0.02038,
#   'market_cap_change_24h': 692735,
#   'market_cap_change_percentage_24h': 0.03879,
#   'circulating_supply': 1789549457.493094,
#   'total_supply': 1789549457.493094,
#   'max_supply': None,
#   'ath': 1.075,
#   'ath_change_percentage': -7.0806,
#   'ath_date': '2025-05-08T21:25:42.071Z',
#   'atl': 0.943422,
#   'atl_change_percentage': 5.83758,
#   'atl_date': '2025-07-08T10:16:34.749Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:44.303Z'},
#  {'id': 'sky',
#   'symbol': 'sky',
#   'name': 'Sky',
#   'image': 'https://coin-images.coingecko.com/coins/images/39925/large/sky.jpg?1724827980',
#   'current_price': 0.074093,
#   'market_cap': 1715787482,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': 1738423906,
#   'total_volume': 11179560,
#   'high_24h': 0.076138,
#   'low_24h': 0.071613,
#   'price_change_24h': 0.00159074,
#   'price_change_percentage_24h': 2.19405,
#   'market_cap_change_24h': 37458879,
#   'market_cap_change_percentage_24h': 2.23192,
#   'circulating_supply': 23157152301.77788,
#   'total_supply': 23462665147.36596,
#   'max_supply': 23462665147.3,
#   'ath': 0.100535,
#   'ath_change_percentage': -26.23976,
#   'ath_date': '2024-12-04T10:13:57.264Z',
#   'atl': 0.03582727,
#   'atl_change_percentage': 106.97929,
#   'atl_date': '2025-02-03T05:01:48.626Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:43.606Z'},
#  {'id': 'pi-network',
#   'symbol': 'pi',
#   'name': 'Pi Network',
#   'image': 'https://coin-images.coingecko.com/coins/images/54342/large/pi_network.jpg?1739347576',
#   'current_price': 0.1649,
#   'market_cap': 1670860513,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 2570554635,
#   'total_volume': 15115379,
#   'high_24h': 0.167071,
#   'low_24h': 0.164071,
#   'price_change_24h': -0.001421730208247596,
#   'price_change_percentage_24h': -0.8548,
#   'market_cap_change_24h': -16124589.778599977,
#   'market_cap_change_percentage_24h': -0.95582,
#   'circulating_supply': 10142200266.49829,
#   'total_supply': 15603385025.38199,
#   'max_supply': 100000000000.0,
#   'ath': 2.99,
#   'ath_change_percentage': -94.48282,
#   'ath_date': '2025-02-26T16:41:03.732Z',
#   'atl': 0.131244,
#   'atl_change_percentage': 25.59217,
#   'atl_date': '2026-02-11T17:06:46.605Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:44.202Z'},
#  {'id': 'aster-2',
#   'symbol': 'aster',
#   'name': 'Aster',
#   'image': 'https://coin-images.coingecko.com/coins/images/69040/large/_ASTER.png?1757326782',
#   'current_price': 0.674353,
#   'market_cap': 1658092740,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': 5275641119,
#   'total_volume': 128602194,
#   'high_24h': 0.682766,
#   'low_24h': 0.658437,
#   'price_change_24h': 0.01558146,
#   'price_change_percentage_24h': 2.36523,
#   'market_cap_change_24h': 38506274,
#   'market_cap_change_percentage_24h': 2.37754,
#   'circulating_supply': 2458559719.12999,
#   'total_supply': 7822529124.595041,
#   'max_supply': 8000000000.0,
#   'ath': 2.41,
#   'ath_change_percentage': -72.00387,
#   'ath_date': '2025-09-24T11:18:14.634Z',
#   'atl': 0.099713,
#   'atl_change_percentage': 576.29064,
#   'atl_date': '2025-09-17T12:05:36.771Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:47.153Z'},
#  {'id': 'htx-dao',
#   'symbol': 'htx',
#   'name': 'HTX DAO',
#   'image': 'https://coin-images.coingecko.com/coins/images/35491/large/Frame_1321318576.png?1708908626',
#   'current_price': 1.77e-06,
#   'market_cap': 1623709170,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': 1623709170,
#   'total_volume': 15258258,
#   'high_24h': 1.78e-06,
#   'low_24h': 1.77e-06,
#   'price_change_24h': -6.343655001e-09,
#   'price_change_percentage_24h': -0.35664,
#   'market_cap_change_24h': -6551768.523030043,
#   'market_cap_change_percentage_24h': -0.40188,
#   'circulating_supply': 916533066327098.8,
#   'total_supply': 916533066327098.8,
#   'max_supply': 999990000000000.0,
#   'ath': 3.75e-06,
#   'ath_change_percentage': -52.74576,
#   'ath_date': '2024-12-04T00:16:20.770Z',
#   'atl': 8.00816e-07,
#   'atl_change_percentage': 121.36683,
#   'atl_date': '2024-08-05T13:31:33.427Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:42.998Z'},
#  {'id': 'pepe',
#   'symbol': 'pepe',
#   'name': 'Pepe',
#   'image': 'https://coin-images.coingecko.com/coins/images/29850/large/pepe-token.jpeg?1696528776',
#   'current_price': 3.67e-06,
#   'market_cap': 1545037728,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': 1545037728,
#   'total_volume': 449022928,
#   'high_24h': 3.75e-06,
#   'low_24h': 3.47e-06,
#   'price_change_24h': 1.86655e-07,
#   'price_change_percentage_24h': 5.35787,
#   'market_cap_change_24h': 79599942,
#   'market_cap_change_percentage_24h': 5.43182,
#   'circulating_supply': 420690000000000.0,
#   'total_supply': 420690000000000.0,
#   'max_supply': 420690000000000.0,
#   'ath': 2.803e-05,
#   'ath_change_percentage': -86.90457,
#   'ath_date': '2024-12-09T16:30:35.828Z',
#   'atl': 5.5142e-08,
#   'atl_change_percentage': 6556.24509,
#   'atl_date': '2023-04-18T02:14:41.591Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:42.783Z'},
#  {'id': 'usdd',
#   'symbol': 'usdd',
#   'name': 'USDD',
#   'image': 'https://coin-images.coingecko.com/coins/images/25380/large/UUSD.jpg?1696524513',
#   'current_price': 1.001,
#   'market_cap': 1543633699,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': 1546614814,
#   'total_volume': 3897274,
#   'high_24h': 1.001,
#   'low_24h': 0.999985,
#   'price_change_24h': 0.00087549,
#   'price_change_percentage_24h': 0.08755,
#   'market_cap_change_24h': 86590646,
#   'market_cap_change_percentage_24h': 5.9429,
#   'circulating_supply': 1542243860.0,
#   'total_supply': 1545222291.0,
#   'max_supply': None,
#   'ath': 1.052,
#   'ath_change_percentage': -4.82943,
#   'ath_date': '2023-10-23T22:45:25.398Z',
#   'atl': 0.928067,
#   'atl_change_percentage': 7.86099,
#   'atl_date': '2022-06-19T16:15:11.558Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:42.219Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://coin-images.coingecko.com/coins/images/12645/large/aave-token-round.png?1720472354',
#   'current_price': 101.13,
#   'market_cap': 1534028063,
#   'market_cap_rank': 55,
#   'fully_diluted_valuation': 1618518664,
#   'total_volume': 332054545,
#   'high_24h': 103.82,
#   'low_24h': 93.42,
#   'price_change_24h': 6.48,
#   'price_change_percentage_24h': 6.84923,
#   'market_cap_change_24h': 98924810,
#   'market_cap_change_percentage_24h': 6.89322,
#   'circulating_supply': 15164761.178472267,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 661.69,
#   'ath_change_percentage': -84.70192,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 26.02,
#   'atl_change_percentage': 288.9841,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:41.733Z'},
#  {'id': 'ripple-usd',
#   'symbol': 'rlusd',
#   'name': 'Ripple USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/39651/large/RLUSD_200x200_%281%29.png?1727376633',
#   'current_price': 0.999926,
#   'market_cap': 1441653953,
#   'market_cap_rank': 56,
#   'fully_diluted_valuation': 1441653953,
#   'total_volume': 143330681,
#   'high_24h': 1.001,
#   'low_24h': 0.999289,
#   'price_change_24h': -5.1276669083666e-05,
#   'price_change_percentage_24h': -0.00513,
#   'market_cap_change_24h': 21066554,
#   'market_cap_change_percentage_24h': 1.48295,
#   'circulating_supply': 1441761093.407245,
#   'total_supply': 1441761093.407245,
#   'max_supply': None,
#   'ath': 1.073,
#   'ath_change_percentage': -6.80487,
#   'ath_date': '2024-12-26T10:45:52.337Z',
#   'atl': 0.962292,
#   'atl_change_percentage': 3.89926,
#   'atl_date': '2024-12-18T04:40:40.880Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:43.662Z'},
#  {'id': 'janus-henderson-anemoy-treasury-fund',
#   'symbol': 'jtrsy',
#   'name': 'Janus Henderson Anemoy Treasury Fund',
#   'image': 'https://coin-images.coingecko.com/coins/images/70445/large/JTRSY.png?1762078582',
#   'current_price': 1.1,
#   'market_cap': 1422339826,
#   'market_cap_rank': 57,
#   'fully_diluted_valuation': 1422339826,
#   'total_volume': 0.0,
#   'high_24h': 1.1,
#   'low_24h': 1.1,
#   'price_change_24h': 7.7e-05,
# ...
#   'total_volume': 12085.79,
#   'high_24h': 0.01238787,
#   'low_24h': 0.01143716,
#   'price_change_24h': 0.00062829,
#   'price_change_percentage_24h': 5.42083,
#   'market_cap_change_24h': 36159868,
#   'market_cap_change_percentage_24h': 5.4935,
#   'circulating_supply': 56829282256.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 0.060147,
#   'ath_change_percentage': -79.6851,
#   'ath_date': '2025-09-14T16:52:41.627Z',
#   'atl': 0.00940996,
#   'atl_change_percentage': 29.8495,
#   'atl_date': '2026-03-30T23:46:20.691Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:52.104Z'},
#  {'id': 'just',
#   'symbol': 'jst',
#   'name': 'JUST',
#   'image': 'https://coin-images.coingecko.com/coins/images/11095/large/JUST.jpg?1696511035',
#   'current_price': 0.078562,
#   'market_cap': 691783005,
#   'market_cap_rank': 84,
#   'fully_diluted_valuation': 691783005,
#   'total_volume': 42722967,
#   'high_24h': 0.080048,
#   'low_24h': 0.074987,
#   'price_change_24h': -0.001137725991202654,
#   'price_change_percentage_24h': -1.42752,
#   'market_cap_change_24h': -11770690.19641149,
#   'market_cap_change_percentage_24h': -1.67303,
#   'circulating_supply': 8815108090.312735,
#   'total_supply': 8815108090.312735,
#   'max_supply': 9900000000.0,
#   'ath': 0.193254,
#   'ath_change_percentage': -59.61569,
#   'ath_date': '2021-04-05T04:34:23.454Z',
#   'atl': 0.00476275,
#   'atl_change_percentage': 1538.64167,
#   'atl_date': '2020-05-09T06:08:54.872Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:41.094Z'},
#  {'id': 'flare-networks',
#   'symbol': 'flr',
#   'name': 'Flare',
#   'image': 'https://coin-images.coingecko.com/coins/images/28624/large/FLR-icon200x200.png?1696527609',
#   'current_price': 0.00802288,
#   'market_cap': 687286001,
#   'market_cap_rank': 85,
#   'fully_diluted_valuation': 846341946,
#   'total_volume': 4061557,
#   'high_24h': 0.00808978,
#   'low_24h': 0.00768648,
#   'price_change_24h': 0.00030325,
#   'price_change_percentage_24h': 3.92827,
#   'market_cap_change_24h': 26320276,
#   'market_cap_change_percentage_24h': 3.98209,
#   'circulating_supply': 85666021025.94635,
#   'total_supply': 105491377464.3142,
#   'max_supply': None,
#   'ath': 0.150073,
#   'ath_change_percentage': -94.65564,
#   'ath_date': '2023-01-10T03:14:05.921Z',
#   'atl': 0.00726058,
#   'atl_change_percentage': 10.46548,
#   'atl_date': '2026-04-07T18:55:08.564Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:42.546Z'},
#  {'id': 'arbitrum',
#   'symbol': 'arb',
#   'name': 'Arbitrum',
#   'image': 'https://coin-images.coingecko.com/coins/images/16547/large/arb.jpg?1721358242',
#   'current_price': 0.11307,
#   'market_cap': 683055151,
#   'market_cap_rank': 86,
#   'fully_diluted_valuation': 1130731726,
#   'total_volume': 72304957,
#   'high_24h': 0.113613,
#   'low_24h': 0.110394,
#   'price_change_24h': 0.00243508,
#   'price_change_percentage_24h': 2.201,
#   'market_cap_change_24h': 14744864,
#   'market_cap_change_percentage_24h': 2.20629,
#   'circulating_supply': 6040824145.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.39,
#   'ath_change_percentage': -95.2698,
#   'ath_date': '2024-01-12T12:29:59.231Z',
#   'atl': 0.087087,
#   'atl_change_percentage': 29.83005,
#   'atl_date': '2026-03-29T22:50:51.753Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:41.996Z'},
#  {'id': 'ousg',
#   'symbol': 'ousg',
#   'name': 'OUSG',
#   'image': 'https://coin-images.coingecko.com/coins/images/29023/large/OUSG.png?1696527993',
#   'current_price': 114.91,
#   'market_cap': 674946796,
#   'market_cap_rank': 87,
#   'fully_diluted_valuation': 674946796,
#   'total_volume': 0.0,
#   'high_24h': 114.91,
#   'low_24h': 114.87,
#   'price_change_24h': 0.035831,
#   'price_change_percentage_24h': 0.03119,
#   'market_cap_change_24h': -1689216.58009243,
#   'market_cap_change_percentage_24h': -0.24965,
#   'circulating_supply': 5873670.758358905,
#   'total_supply': 5873670.758358905,
#   'max_supply': None,
#   'ath': 114.91,
#   'ath_change_percentage': 0.0,
#   'ath_date': '2026-04-13T21:15:07.634Z',
#   'atl': 95.09,
#   'atl_change_percentage': 20.84325,
#   'atl_date': '2023-03-22T20:00:17.106Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:25:07.043Z'},
#  {'id': 'official-trump',
#   'symbol': 'trump',
#   'name': 'Official Trump',
#   'image': 'https://coin-images.coingecko.com/coins/images/53746/large/trump.png?1737171561',
#   'current_price': 2.84,
#   'market_cap': 659637726,
#   'market_cap_rank': 88,
#   'fully_diluted_valuation': 2837166061,
#   'total_volume': 100990226,
#   'high_24h': 2.88,
#   'low_24h': 2.8,
#   'price_change_24h': 0.02986192,
#   'price_change_percentage_24h': 1.06392,
#   'market_cap_change_24h': 7314091,
#   'market_cap_change_percentage_24h': 1.12124,
#   'circulating_supply': 232498807.465716,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 73.43,
#   'ath_change_percentage': -96.13516,
#   'ath_date': '2025-01-19T11:50:34.806Z',
#   'atl': 2.73,
#   'atl_change_percentage': 3.94994,
#   'atl_date': '2026-03-12T14:42:04.966Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:44.337Z'},
#  {'id': 'xdce-crowd-sale',
#   'symbol': 'xdc',
#   'name': 'XDC Network',
#   'image': 'https://coin-images.coingecko.com/coins/images/2912/large/xdc-icon.png?1696503661',
#   'current_price': 0.03134422,
#   'market_cap': 623831850,
#   'market_cap_rank': 89,
#   'fully_diluted_valuation': 1190622979,
#   'total_volume': 20934562,
#   'high_24h': 0.03151569,
#   'low_24h': 0.03023433,
#   'price_change_24h': 0.00056403,
#   'price_change_percentage_24h': 1.83243,
#   'market_cap_change_24h': 10095531,
#   'market_cap_change_percentage_24h': 1.64493,
#   'circulating_supply': 19942478754.87,
#   'total_supply': 38061496036.35,
#   'max_supply': None,
#   'ath': 0.192754,
#   'ath_change_percentage': -83.79725,
#   'ath_date': '2021-08-21T04:39:48.324Z',
#   'atl': 0.00039532,
#   'atl_change_percentage': 7800.33725,
#   'atl_date': '2019-07-22T00:00:00.000Z',
#   'roi': {'times': 0.7438366212907899,
#    'currency': 'eth',
#    'percentage': 74.38366212907899},
#   'last_updated': '2026-04-14T09:27:42.315Z'},
#  {'id': 'beldex',
#   'symbol': 'bdx',
#   'name': 'Beldex',
#   'image': 'https://coin-images.coingecko.com/coins/images/5111/large/Beldex.png?1696505631',
#   'current_price': 0.080153,
#   'market_cap': 620370388,
#   'market_cap_rank': 90,
#   'fully_diluted_valuation': 796728819,
#   'total_volume': 12517144,
#   'high_24h': 0.080605,
#   'low_24h': 0.080103,
#   'price_change_24h': -0.000112554637986415,
#   'price_change_percentage_24h': -0.14023,
#   'market_cap_change_24h': -1301183.7030787468,
#   'market_cap_change_percentage_24h': -0.2093,
#   'circulating_supply': 7737531580.593689,
#   'total_supply': 9937151293.94547,
#   'max_supply': None,
#   'ath': 0.450785,
#   'ath_change_percentage': -82.21371,
#   'ath_date': '2018-12-17T00:00:00.000Z',
#   'atl': 0.00027519,
#   'atl_change_percentage': 29035.94247,
#   'atl_date': '2019-11-01T11:05:12.090Z',
#   'roi': {'times': -0.6793873255058575,
#    'currency': 'usd',
#    'percentage': -67.93873255058574},
#   'last_updated': '2026-04-14T09:27:43.872Z'},
#  {'id': 'jupiter-exchange-solana',
#   'symbol': 'jup',
#   'name': 'Jupiter',
#   'image': 'https://coin-images.coingecko.com/coins/images/34188/large/jup.png?1704266489',
#   'current_price': 0.169943,
#   'market_cap': 603476197,
#   'market_cap_rank': 91,
#   'fully_diluted_valuation': 1166556340,
#   'total_volume': 22819458,
#   'high_24h': 0.171375,
#   'low_24h': 0.162546,
#   'price_change_24h': 0.00708283,
#   'price_change_percentage_24h': 4.34904,
#   'market_cap_change_24h': 25074265,
#   'market_cap_change_percentage_24h': 4.33509,
#   'circulating_supply': 3550835739.32,
#   'total_supply': 6863982317.534854,
#   'max_supply': 10000000000.0,
#   'ath': 2.0,
#   'ath_change_percentage': -91.48462,
#   'ath_date': '2024-01-31T15:02:47.304Z',
#   'atl': 0.135801,
#   'atl_change_percentage': 25.41051,
#   'atl_date': '2026-02-12T18:35:44.925Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:49.457Z'},
#  {'id': 'vechain',
#   'symbol': 'vet',
#   'name': 'VeChain',
#   'image': 'https://coin-images.coingecko.com/coins/images/1167/large/VET.png?1742383283',
#   'current_price': 0.00696537,
#   'market_cap': 598884512,
#   'market_cap_rank': 92,
#   'fully_diluted_valuation': 598884512,
#   'total_volume': 16498605,
#   'high_24h': 0.00709747,
#   'low_24h': 0.00675494,
#   'price_change_24h': 0.00019399,
#   'price_change_percentage_24h': 2.86492,
#   'market_cap_change_24h': 16688046,
#   'market_cap_change_percentage_24h': 2.86639,
#   'circulating_supply': 85985041177.0,
#   'total_supply': 85985041177.0,
#   'max_supply': 86712634466.0,
#   'ath': 0.280991,
#   'ath_change_percentage': -97.51256,
#   'ath_date': '2021-04-19T01:08:21.675Z',
#   'atl': 0.00191713,
#   'atl_change_percentage': 264.57962,
#   'atl_date': '2020-03-13T02:29:59.652Z',
#   'roi': {'times': 0.01994910670125025,
#    'currency': 'eth',
#    'percentage': 1.994910670125025},
#   'last_updated': '2026-04-14T09:27:41.231Z'},
#  {'id': 'midnight-3',
#   'symbol': 'night',
#   'name': 'Midnight',
#   'image': 'https://coin-images.coingecko.com/coins/images/71015/large/midnight.png?1765193080',
#   'current_price': 0.03586218,
#   'market_cap': 596452468,
#   'market_cap_rank': 93,
#   'fully_diluted_valuation': 861956703,
#   'total_volume': 38117028,
#   'high_24h': 0.03945195,
#   'low_24h': 0.03547311,
#   'price_change_24h': -0.003203492537378554,
#   'price_change_percentage_24h': -8.20027,
#   'market_cap_change_24h': -52335659.18814182,
#   'market_cap_change_percentage_24h': -8.06668,
#   'circulating_supply': 16607399400.63495,
#   'total_supply': 24000000000.0,
#   'max_supply': 24000000000.0,
#   'ath': 0.118529,
#   'ath_change_percentage': -69.66001,
#   'ath_date': '2025-12-09T09:29:38.386Z',
#   'atl': 0.02378032,
#   'atl_change_percentage': 51.22457,
#   'atl_date': '2025-12-09T09:48:36.670Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:45.705Z'},
#  {'id': 'gho',
#   'symbol': 'gho',
#   'name': 'GHO',
#   'image': 'https://coin-images.coingecko.com/coins/images/30663/large/gho-token-logo.png?1720517092',
#   'current_price': 0.999477,
#   'market_cap': 583691969,
#   'market_cap_rank': 94,
#   'fully_diluted_valuation': 583691969,
#   'total_volume': 9767833,
#   'high_24h': 1.0,
#   'low_24h': 0.999084,
#   'price_change_24h': 8.12e-06,
#   'price_change_percentage_24h': 0.00081,
#   'market_cap_change_24h': -19230.712672472,
#   'market_cap_change_percentage_24h': -0.00329,
#   'circulating_supply': 584000000.0,
#   'total_supply': 584000000.0,
#   'max_supply': None,
#   'ath': 1.03,
#   'ath_change_percentage': -2.94824,
#   'ath_date': '2024-02-28T17:15:58.387Z',
#   'atl': 0.917065,
#   'atl_change_percentage': 8.98679,
#   'atl_date': '2023-10-24T04:41:04.568Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:42.656Z'},
#  {'id': 'ylds',
#   'symbol': 'ylds',
#   'name': 'YLDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/66486/large/YLDS.png?1772560579',
#   'current_price': 0.999736,
#   'market_cap': 578216605,
#   'market_cap_rank': 95,
#   'fully_diluted_valuation': 578216605,
#   'total_volume': 2105578,
#   'high_24h': 0.99993,
#   'low_24h': 0.999707,
#   'price_change_24h': -0.00014348258852992,
#   'price_change_percentage_24h': -0.01435,
#   'market_cap_change_24h': -22907036.55199325,
#   'market_cap_change_percentage_24h': -3.8107,
#   'circulating_supply': 578312365.69,
#   'total_supply': 578312365.69,
#   'max_supply': None,
#   'ath': 1.001,
#   'ath_change_percentage': -0.12492,
#   'ath_date': '2026-02-13T15:00:58.249Z',
#   'atl': 0.999202,
#   'atl_change_percentage': 0.06331,
#   'atl_date': '2025-11-16T12:26:29.488Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:44.726Z'},
#  {'id': 'stable-2',
#   'symbol': 'stable',
#   'name': '\u200b\u200bStable',
#   'image': 'https://coin-images.coingecko.com/coins/images/69242/large/stable-logotype-framed-square-light.png?1762753913',
#   'current_price': 0.02638713,
#   'market_cap': 574443371,
#   'market_cap_rank': 96,
#   'fully_diluted_valuation': 2638185841,
#   'total_volume': 46920124,
#   'high_24h': 0.03075438,
#   'low_24h': 0.02531759,
#   'price_change_24h': -0.002846047839553799,
#   'price_change_percentage_24h': -9.73568,
#   'market_cap_change_24h': -61278493.67196667,
#   'market_cap_change_percentage_24h': -9.6392,
#   'circulating_supply': 21774181412.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 0.0388874,
#   'ath_change_percentage': -32.23799,
#   'ath_date': '2026-02-27T01:55:43.571Z',
#   'atl': 0.0092214,
#   'atl_change_percentage': 185.75799,
#   'atl_date': '2025-12-24T05:49:32.232Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:45.481Z'},
#  {'id': 'usual-usd',
#   'symbol': 'usd0',
#   'name': 'Usual USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/38272/large/USD0LOGO.png?1716962811',
#   'current_price': 0.998111,
#   'market_cap': 557838522,
#   'market_cap_rank': 97,
#   'fully_diluted_valuation': 557838522,
#   'total_volume': 523220,
#   'high_24h': 1.001,
#   'low_24h': 0.992426,
#   'price_change_24h': 0.00180755,
#   'price_change_percentage_24h': 0.18143,
#   'market_cap_change_24h': 609241,
#   'market_cap_change_percentage_24h': 0.10933,
#   'circulating_supply': 558894364.9639908,
#   'total_supply': 558894364.9639908,
#   'max_supply': None,
#   'ath': 1.33,
#   'ath_change_percentage': -24.70841,
#   'ath_date': '2024-07-12T08:28:59.311Z',
#   'atl': 0.962885,
#   'atl_change_percentage': 3.66144,
#   'atl_date': '2025-04-10T08:30:51.088Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:43.236Z'},
#  {'id': 'siren-2',
#   'symbol': 'siren',
#   'name': 'Siren',
#   'image': 'https://coin-images.coingecko.com/coins/images/54479/large/siren.png?1739960056',
#   'current_price': 0.751863,
#   'market_cap': 548375755,
#   'market_cap_rank': 98,
#   'fully_diluted_valuation': 548375755,
#   'total_volume': 17519234,
#   'high_24h': 0.812821,
#   'low_24h': 0.726726,
#   'price_change_24h': -0.037545643156849384,
#   'price_change_percentage_24h': -4.75618,
#   'market_cap_change_24h': -23708693.34662342,
#   'market_cap_change_percentage_24h': -4.14426,
#   'circulating_supply': 727274305.0434376,
#   'total_supply': 727274305.0434376,
#   'max_supply': 1000000000.0,
#   'ath': 3.61,
#   'ath_change_percentage': -79.07802,
#   'ath_date': '2026-03-22T17:26:33.134Z',
#   'atl': 0.02634736,
#   'atl_change_percentage': 2762.74657,
#   'atl_date': '2025-03-11T06:21:52.561Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:44.401Z'},
#  {'id': 'fetch-ai',
#   'symbol': 'fet',
#   'name': 'Artificial Superintelligence Alliance',
#   'image': 'https://coin-images.coingecko.com/coins/images/5681/large/ASI.png?1719827289',
#   'current_price': 0.235202,
#   'market_cap': 531518634,
#   'market_cap_rank': 99,
#   'fully_diluted_valuation': 638724802,
#   'total_volume': 83406832,
#   'high_24h': 0.23996,
#   'low_24h': 0.226729,
#   'price_change_24h': 0.00659153,
#   'price_change_percentage_24h': 2.8833,
#   'market_cap_change_24h': 15372900,
#   'market_cap_change_percentage_24h': 2.9784,
#   'circulating_supply': 2258791208.4351873,
#   'total_supply': 2714384546.672,
#   'max_supply': 2714384546.672,
#   'ath': 3.45,
#   'ath_change_percentage': -93.16568,
#   'ath_date': '2024-03-28T17:21:18.050Z',
#   'atl': 0.00816959,
#   'atl_change_percentage': 2789.58756,
#   'atl_date': '2020-03-13T02:24:18.347Z',
#   'roi': {'times': 1.7128309097590761,
#    'currency': 'usd',
#    'percentage': 171.2830909759076},
#   'last_updated': '2026-04-14T09:27:44.958Z'},
#  {'id': 'bonk',
#   'symbol': 'bonk',
#   'name': 'Bonk',
#   'image': 'https://coin-images.coingecko.com/coins/images/28600/large/bonk.jpg?1696527587',
#   'current_price': 5.93e-06,
#   'market_cap': 522021417,
#   'market_cap_rank': 100,
#   'fully_diluted_valuation': 522021417,
#   'total_volume': 71402537,
#   'high_24h': 6.14e-06,
#   'low_24h': 5.61e-06,
#   'price_change_24h': 3.02138e-07,
#   'price_change_percentage_24h': 5.36727,
#   'market_cap_change_24h': 26944826,
#   'market_cap_change_percentage_24h': 5.44256,
#   'circulating_supply': 87994740501212.19,
#   'total_supply': 87994740501285.75,
#   'max_supply': 87995282867000.55,
#   'ath': 5.825e-05,
#   'ath_change_percentage': -89.81359,
#   'ath_date': '2024-11-20T04:01:06.465Z',
#   'atl': 8.6142e-08,
#   'atl_change_percentage': 6788.12552,
#   'atl_date': '2022-12-29T22:48:46.755Z',
#   'roi': None,
#   'last_updated': '2026-04-14T09:27:50.526Z'}]

# %%
# get_market_chart() 응답 내용(JSON) 확인
market_caps
# Out:
# [[1744675200000, 60199908506.245766],
#  [1744761600000, 60417188776.17674],
#  [1744848000000, 60482834985.68738],
#  [1744934400000, 60905068137.7922],
#  [1745020800000, 60899531624.784546],
#  [1745107200000, 60905279546.47661],
#  [1745193600000, 60912555306.20599],
#  [1745280000000, 60928832833.85901],
#  [1745366400000, 61589269101.35528],
#  [1745452800000, 61896921299.12466],
#  [1745539200000, 62129850660.586266],
#  [1745625600000, 62325968054.99818],
#  [1745712000000, 62251662906.80433],
#  [1745798400000, 62076749988.76833],
#  [1745884800000, 62026261648.921],
#  [1745971200000, 62142665088.87474],
#  [1746057600000, 61508869555.16433],
#  [1746144000000, 61469063386.18792],
#  [1746230400000, 61520122153.8279],
#  [1746316800000, 61504588129.61178],
#  [1746403200000, 61502292587.1267],
#  [1746489600000, 61786628299.92093],
#  [1746576000000, 60949351180.20576],
#  [1746662400000, 60947364928.44116],
#  [1746748800000, 60867341067.19171],
#  [1746835200000, 60689997043.40309],
#  [1746921600000, 60800003218.424],
#  [1747008000000, 60801300532.30528],
#  [1747094400000, 60886438189.638725],
#  [1747180800000, 60861380673.33633],
#  [1747267200000, 60631968614.49602],
#  [1747353600000, 60575195332.76094],
#  [1747440000000, 60805371271.162575],
#  [1747526400000, 60894170790.318344],
#  [1747612800000, 60855229769.997635],
#  [1747699200000, 60617499885.70176],
